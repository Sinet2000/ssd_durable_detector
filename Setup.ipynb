# %% [markdown]
# 1. Instalēt TensorFlow objektu noteikšanas pakotnes

# %%
# !sudo apt install unzip
# !unzip /home/midtempo/SSD/trained_model/custom_model_lite.zip

# %%
# Clone the tensorflow models repository from GitHub
# !pip uninstall Cython -y # Temporary fix for "No module named 'object_detection'" error
# !git clone -b r2.12.0 https://github.com/tensorflow/models.git
# !cd models && git checkout 115409fcafdf5098855c8ca18c4f87c14174ffe1
# Out:
# WARNING: Skipping Cython as it is not installed.
# Cloning into 'models'...
# remote: Enumerating objects: 97260, done.
# remote: Counting objects: 100% (540/540), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 97260 (delta 320), reused 455 (delta 272), pack-reused 96720
# Receiving objects: 100% (97260/97260), 612.91 MiB | 8.30 MiB/s, done.
# Resolving deltas: 100% (70738/70738), done.
# Note: switching to '115409fcafdf5098855c8ca18c4f87c14174ffe1'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 115409fca Internal change

# %%
pip install tensorflow
pip install opencv-python
pip uninstall protobuf
# pip install protobuf==3.20.0

# %%
# Update package lists and install wget
sudo apt update
sudo apt install wget unzip

# Download and unzip protoc 3.20.1
wget https://github.com/protocolbuffers/protobuf/releases/download/v3.20.1/protoc-3.20.1-linux-x86_64.zip
unzip protoc-3.20.1-linux-x86_64.zip -d protoc-3.20.1

# Move the binaries to /usr/local/bin and includes to /usr/local/include
sudo mv protoc-3.20.1/bin/protoc /usr/local/bin/
sudo mv protoc-3.20.1/include/* /usr/local/include/

# Verify the installation
protoc --version

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
import re
import os

# Get the current working directory
cwd = os.getcwd()

input_path = os.path.join(cwd, 'models/research/object_detection/packages/tf2/setup.py')
output_path = os.path.join(cwd, 'models/research/setup.py')

# Read the content of the input setup.py file
with open(input_path, 'r') as f:
    content = f.read()

# Modify the tf-models-official version requirement
modified_content = re.sub(r'tf-models-official>=2.5.1', r'tf-models-official==2.8.0', content)

# Write the modified content to the output setup.py file
with open(output_path, 'w') as f:
    f.write(modified_content)

# %%
# Need to do a temporary fix with PyYAML because Colab isn't able to install PyYAML v5.4.1
# !pip install pyyaml==5.3
# !pip install /home/midtempo/SSD/models/research/

# Need to downgrade to TF v2.8.0 due to Colab compatibility bug with TF v2.10 (as of 10/03/22)
# !pip install tensorflow==2.8.0

# Install CUDA version 11.0 (to maintain compatibility with TF v2.8.0)
# !pip install tensorflow_io==0.23.1
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget http://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !apt-key add /var/cuda-repo-ubuntu1804-11-0-local/7fa2af80.pub
# !apt-get update && sudo apt-get install cuda-toolkit-11-0
# !export LD_LIBRARY_PATH=/usr/local/cuda-11.0/lib64:$LD_LIBRARY_PATH
# Out:
# Collecting pyyaml==5.3
#   Downloading PyYAML-5.3.tar.gz (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.2/268.2 kB 457.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3-cp39-cp39-linux_x86_64.whl size=44244 sha256=b41736825708d58105101f88e99d4f3455fec0b36a61a24943518e904755b80b
#   Stored in directory: /home/midtempo/.cache/pip/wheels/b8/91/58/7cbe3f1dd6ba39ab89041441e6e01fc8361fbddac40aaea52d
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
# Successfully installed pyyaml-5.3
# ERROR: Invalid requirement: '/content/models/research/'
# Hint: It looks like a path. File '/content/models/research/' does not exist.
# Collecting tensorflow==2.8.0
#   Downloading tensorflow-2.8.0-cp39-cp39-manylinux2010_x86_64.whl.metadata (2.9 kB)
# Collecting absl-py>=0.4.0 (from tensorflow==2.8.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.8.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=1.12 (from tensorflow==2.8.0)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast>=0.2.1 (from tensorflow==2.8.0)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.8.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.8.0)
#   Downloading h5py-3.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=9.0.1 (from tensorflow==2.8.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting numpy>=1.20 (from tensorflow==2.8.0)
#   Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.8.0)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0)
#   Downloading protobuf-5.27.0-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from tensorflow==2.8.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.8.0)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from tensorflow==2.8.0) (4.12.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.8.0)
#   Downloading wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0)
#   Downloading tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8.0)
#   Downloading keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.8.0)
#   Downloading tensorflow_io_gcs_filesystem-0.37.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.8.0)
#   Downloading grpcio-1.64.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.43.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.32.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /home/midtempo/miniconda3/envs/tf-ssd/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.19.0)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.8.0-cp39-cp39-manylinux2010_x86_64.whl (497.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 4.5 MB/s eta 0:00:0000:0100:02m
# Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 16.1 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 8.9 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.3 MB/s eta 0:00:00
# Downloading grpcio-1.64.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 18.4 MB/s eta 0:00:0000:0100:01
# Downloading h5py-3.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 18.0 MB/s eta 0:00:0000:0100:01
# Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.2 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 18.6 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 15.6 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.4 MB/s eta 0:00:00
# Downloading protobuf-5.27.0-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 15.2 MB/s eta 0:00:00
# Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 19.6 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_io_gcs_filesystem-0.37.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.1/80.1 kB 6.4 MB/s eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 12.5 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 20.4 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 15.3 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 12.4 MB/s eta 0:00:00
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 14.0 MB/s eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 6.7 MB/s eta 0:00:00
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, libclang, keras, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, markdown, keras-preprocessing, h5py, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 flatbuffers-24.3.25 gast-0.5.4 google-auth-2.29.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.64.0 h5py-3.11.0 keras-2.8.0 keras-preprocessing-1.1.2 libclang-18.1.1 markdown-3.6 numpy-1.26.4 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-5.27.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.37.0 termcolor-2.4.0 tf-estimator-nightly-2.8.0.dev2021122109 werkzeug-3.0.3 wrapt-1.16.0
# Collecting tensorflow_io==0.23.1
#   Downloading tensorflow_io-0.23.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting tensorflow-io-gcs-filesystem==0.23.1 (from tensorflow_io==0.23.1)
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Downloading tensorflow_io-0.23.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 8.7 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow_io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.37.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.37.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.37.0
# Successfully installed tensorflow-io-gcs-filesystem-0.23.1 tensorflow_io-0.23.1

# %%
# Run Model Bulider Test file, just to verify everything's working properly
# !python ./models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2024-05-29 20:34:03.810715: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:03.810761: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-05-29 20:34:07.492328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-29 20:34:07.492498: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:07.492584: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:07.492643: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:07.492697: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:07.647958: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2024-05-29 20:34:07.648200: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Running tests under Python 3.9.19: /home/midtempo/miniconda3/envs/tf-ssd/bin/python
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2024-05-29 20:34:07.653937: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home
140354758796352 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0529 20:34:19.468356 140354758796352 efficientnet_model.py:144] round_filter input=32 output=56
# I0529 20:34:19.479763 140354758796352 efficientnet_model.py:144] round_filter input=32 output=56
# I0529 20:34:19.479909 140354758796352 efficientnet_model.py:144] round_filter input=16 output=32
# I0529 20:34:19.627236 140354758796352 efficientnet_model.py:144] round_filter input=16 output=32
# I0529 20:34:19.627376 140354758796352 efficientnet_model.py:144] round_filter input=24 output=40
# I0529 20:34:19.932389 140354758796352 efficientnet_model.py:144] round_filter input=24 output=40
# I0529 20:34:19.932540 140354758796352 efficientnet_model.py:144] round_filter input=40 output=72
# I0529 20:34:20.249354 140354758796352 efficientnet_model.py:144] round_filter input=40 output=72
# I0529 20:34:20.249526 140354758796352 efficientnet_model.py:144] round_filter input=80 output=144
# I0529 20:34:20.697179 140354758796352 efficientnet_model.py:144] round_filter input=80 output=144
# I0529 20:34:20.697322 140354758796352 efficientnet_model.py:144] round_filter input=112 output=200
# I0529 20:34:21.157509 140354758796352 efficientnet_model.py:144] round_filter input=112 output=200
# I0529 20:34:21.157648 140354758796352 efficientnet_model.py:144] round_filter input=192 output=344
# I0529 20:34:21.847325 140354758796352 efficientnet_model.py:144] round_filter input=192 output=344
# I0529 20:34:21.847515 140354758796352 efficientnet_model.py:144] round_filter input=320 output=576
# I0529 20:34:22.060473 140354758796352 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0529 20:34:22.086845 140354758796352 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0529 20:34:22.140380 140354758796352 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0529 20:34:22.140515 140354758796352 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0529 20:34:22.140553 140354758796352 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0529 20:34:22.141411 140354758796352 efficientnet_model.py:144] round_filter input=32 output=64
# I0529 20:34:22.150923 140354758796352 efficientnet_model.py:144] round_filter input=32 output=64
# I0529 20:34:22.151055 140354758796352 efficientnet_model.py:144] round_filter input=16 output=32
# I0529 20:34:22.293008 140354758796352 efficientnet_model.py:144] round_filter input=16 output=32
# I0529 20:34:22.293146 140354758796352 efficientnet_model.py:144] round_filter input=24 output=48
# I0529 20:34:22.636438 140354758796352 efficientnet_model.py:144] round_filter input=24 output=48
# I0529 20:34:22.636577 140354758796352 efficientnet_model.py:144] round_filter input=40 output=80
# I0529 20:34:23.204657 140354758796352 efficientnet_model.py:144] round_filter input=40 output=80
# I0529 20:34:23.204790 140354758796352 efficientnet_model.py:144] round_filter input=80 output=160
# I0529 20:34:23.723451 140354758796352 efficientnet_model.py:144] round_filter input=80 output=160
# I0529 20:34:23.723590 140354758796352 efficientnet_model.py:144] round_filter input=112 output=224
# I0529 20:34:24.303574 140354758796352 efficientnet_model.py:144] round_filter input=112 output=224
# I0529 20:34:24.303754 140354758796352 efficientnet_model.py:144] round_filter input=192 output=384
# I0529 20:34:25.160894 140354758796352 efficientnet_model.py:144] round_filter input=192 output=384
# I0529 20:34:25.161068 140354758796352 efficientnet_model.py:144] round_filter input=320 output=640
# I0529 20:34:25.449864 140354758796352 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0529 20:34:25.482772 140354758796352 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.43s
# I0529 20:34:25.547523 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.43s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0529 20:34:25.556259 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0529 20:34:25.557765 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0529 20:34:25.558352 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0529 20:34:25.559412 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0529 20:34:25.560256 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0529 20:34:25.560565 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0529 20:34:25.561155 140354758796352 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 17.911s
#
# OK (skipped=1)

# %% [markdown]
# #  Run TensorFlow Lite Model!

# %%
curl https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/TFLite_detection_image.py --output TFLite_detection_image.py

# %%
python TFLite_detection_image.py --modeldir=ssd_model_lite --imagedir images --save_results --noshow_results
